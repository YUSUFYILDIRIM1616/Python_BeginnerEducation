# %% [markdown]
# #DEĞİŞKENLER
# Verileri saklamamızı sağlayan yapılardır. Diyelim ki kullanıcı bilgisayara bilgi girdi.Girilen bilgiyi ben programımda işlemek istersem onu bir değişkenin içine saklarım.

# %%
#Bir değişken oluşturalım.
#Değişken adimi ve soyadimi saklasin
adsoyad = "Yusuf Yıldırım"
yas = 12
print(adsoyad) #Değişkenler print edilmezse ekranda gözükmez!
print(yas)
# Out:
# Yusuf Yıldırım
# 12

# %% [markdown]
# #Degiskenlerin Özellikleri
# 1. Değişkenler amacına göre isimlendirilir.
# 2. İsim verilirken Türkçe karakter kullanılmaz.
# 3. Değişkenler,sayı,metin,kesirli sayı, Doğru/Yanlış değerlerini alabilir.

# %%
#Farklı değişken türleri
arabanin_ismi = "Tesla" #Metin -> String (str) dememktir.
arabanin_motor_gucu = 400 # Sayı -> Integer (int) demektir.
arabanin_yuksekligi = 123.9 # Yükseklik -> Float (f) demektir.
arabanin_genisligi = 95.9 # Ondalıklı sayı -> Double (d) demektir.
araba_calisiyor_mu = True # Doğru/yanlış -> Boolean (bool) demektir.
araba_pahali_mi = False # Doğru/yanlış -> Boolean (bool) demektir.
Print("arabanin_ismi,arabanin_motor_gucu,arabanin_yuksekligi,arabanin_genisligi,araba_calisiyor_mu,araba_pahali_mi")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f231d008b344> in <cell line: 8>()
#       6 araba_calisiyor_mu = True # Doğru/yanlış -> Boolean (bool) demektir.
#       7 araba_pahali_mi = False # Doğru/yanlış -> Boolean (bool) demektir.
# ----> 8 Print(arabanin_ismi,arabanin_motor_gucu,arabanin_yuksekligi,arabanin_genisligi,araba_calisiyor_mu,araba_pahali_mi)
#
# NameError: name 'Print' is not defined

# %% [markdown]
# #Ödevler
# 1. Tarihi bir kişiliğin hayatını seçin.
# 2. Kişinin bilgilerini değişkenlerin içine yazın.Ama değişkenlerin adını amacına uygun yazın !
# 3. Örneğin,ad_soyad ="Mustafa Kemal Atatürk" vb. şeklinde
# 4. Girmeniz gereken(oluşturmanız gereken değişkenler) şunlardır:a.Ad Soyad b.
# Doğduğu Yıl c. Öldüğü yıl (Varsa-olmayabilir) d. Erkek mi veya Kadın mı? e. Şu an
# hayatta mı ? (Doğru/yanlış)f. Mesleği g. Kısa bir şekilde önemli kişiliğini açıkla (2 cümle)
# 5. Girilen değişkenleri print ile ekrana yazdırın.
