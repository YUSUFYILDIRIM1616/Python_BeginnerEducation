# %% [markdown]
# #Değişkenler Genel Tekrar
# Değişkeni tanımlamak için 3 şey gerekir.
# Değişkenin_Adi = Değişkenin Değeri
# Ad_Soyad = "Fevzi Çakmak"
# ad = "Fevzi"
# soyad = "Çakmak"Değişken = Veri Saklama Aracıdır.

# %%
ad = "Yusuf"
print(ad)
"Yeni Kod"
ad = "x"
print(ad)
ad =Input("Lütfen adınızı yazınız: ")
print(ad)
ad = Input("Oyuncu adinizi yaziniz: ")
print(ad)
# Out:
# Yusuf
# x
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-42bd72af61fa> in <cell line: 6>()
#       4 ad = "x"
#       5 print(ad)
# ----> 6 ad =Input("Lütfen adınızı yazınız: ")
#       7 print(ad)
#       8 ad = Input("Oyuncu adinizi yaziniz: ")
#
# NameError: name 'Input' is not defined

# %% [markdown]
# #Kullanıcıdan Değer Alarak Değişken Oluşturma
# Değişkenlerin sadece yazılımcının verdiği değer ile çalıştırmayız.
# Kullanıcıdan da değer alırız.

# %%
*  **Yazılımcının Değişkene Değer Ataması** <br>
*  **Kullanıcının Değişkene Değer Ataması** <br>
Ad = İnput("Lütfen bir değer giriniz:")
#Sonuç olarak **İnput** komudu bizim kullanıcıdan veri almamızı sağlıyor.

# %%
#Kullanıcıdan adının ve soyadının girilmesini isteyin.Girilen ad ve soyad farklı değişkenlerde olsun.
#"Merhaba adı Yusuf ve soyadı Yıldırım olan kişi!" bu yazıyı ekrana yazdırın!
ad = Input ("Lütfen adınızı giriniz:")
soyad = Input ("Lütfen soyadınızı giriniz:")
print("Merhaba "+ad+" ve soyadı "+soyad+" olan kişi!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cb84bbbadb19> in <cell line: 3>()
#       1 #Kullanıcıdan adının ve soyadının girilmesini isteyin.Girilen ad ve soyad farklı değişkenlerde olsun.
#       2 #"Merhaba adı Yusuf ve soyadı Yıldırım olan kişi!" bu yazıyı ekrana yazdırın!
# ----> 3 ad = Input ("Lütfen adınızı giriniz:")
#       4 soyad = Input ("Lütfen soyadınızı giriniz:")
#       5 print("Merhaba "+ad+" ve soyadı "+soyad+" olan kişi!")
#
# NameError: name 'Input' is not defined
